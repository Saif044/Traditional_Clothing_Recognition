# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.5 MB/s eta 0:00:00

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Master_Course/Project
# Out:
# /content/drive/My Drive/Master_Course/Project

# %%
version = 2
img_path = 'test_images'
model_path = f'models/cloth-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1
#
# **Target:** cowboy hat

# %%
img = Image.open(f'{img_path}/sharee.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
model.predict(f'{img_path}/sharee.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Indian Saree-Sari',
#  tensor(4),
#  tensor([6.4993e-06, 2.0907e-02, 1.2070e-05, 2.5439e-06, 9.7864e-01, 3.9265e-06,
#          7.5282e-06, 2.3088e-07, 1.3198e-05, 3.4895e-05, 1.0751e-06, 2.1129e-06,
#          2.6307e-05, 2.3781e-05, 2.3463e-04, 7.4425e-06, 7.7027e-05]))

# %% [markdown]
# # Inference 2
#
# **Target:** beanie cap

# %%
img = Image.open(f'{img_path}/lungi.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/lungi.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Bangladeshi Lungi',
#  tensor(0),
#  tensor([1.0000e+00, 4.4856e-07, 4.6050e-08, 1.1408e-08, 3.4203e-08, 2.7168e-10,
#          6.6342e-09, 3.8143e-10, 2.0420e-09, 1.5337e-10, 1.1862e-10, 3.3642e-10,
#          1.4607e-07, 8.9975e-07, 7.1228e-10, 7.4326e-08, 9.0766e-10]))

# %% [markdown]
# # Inference 3
# **Target:** taqiyah cap

# %%
img = Image.open(f'{img_path}/kilt.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=96x128>

# %%
model.predict(f'{img_path}/kilt.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Scottish Kilt',
#  tensor(15),
#  tensor([8.2864e-11, 5.7798e-12, 1.3212e-11, 9.6863e-10, 5.2650e-14, 3.2617e-11,
#          7.2946e-11, 1.0448e-10, 4.2838e-13, 1.7267e-12, 3.5737e-12, 3.5807e-10,
#          4.7091e-13, 1.4686e-12, 8.5458e-13, 1.0000e+00, 2.4263e-13]))

# %% [markdown]
# # Inference 4
# **Target:** boater hat

# %%
img = Image.open(f'{img_path}/kimono.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/kimono.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Japanese Kimono',
#  tensor(6),
#  tensor([3.7118e-07, 3.0783e-06, 1.2208e-08, 5.1165e-08, 3.8061e-07, 4.0622e-06,
#          9.9918e-01, 5.4508e-05, 5.1457e-08, 1.8516e-07, 3.8703e-08, 9.1712e-10,
#          3.9993e-04, 2.4988e-06, 5.2415e-10, 3.8089e-08, 3.5499e-04]))

# %% [markdown]
# ## Inference 5

# %%
img = Image.open(f'{img_path}/regalia.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=143x256>

# %%
model.predict(f'{img_path}/regalia.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Native American Regalia',
#  tensor(11),
#  tensor([4.2985e-09, 8.4794e-12, 4.1130e-09, 2.9939e-10, 7.3538e-10, 5.5413e-08,
#          4.8100e-10, 1.1847e-10, 2.4974e-10, 9.7177e-09, 5.4620e-08, 1.0000e+00,
#          8.1087e-11, 1.3718e-08, 6.0999e-09, 1.1678e-07, 1.7203e-08]))

# %% [markdown]
# ## Inference 6

# %%
img = Image.open(f'{img_path}/panjabi1.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=192x256>

# %%
model.predict(f'{img_path}/panjabi1.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Bangladeshi Panjabi',
#  tensor(1),
#  tensor([1.4071e-07, 9.9999e-01, 2.6312e-08, 9.8144e-09, 3.3642e-09, 6.2399e-07,
#          8.9324e-09, 2.9273e-08, 7.0185e-08, 5.5778e-06, 9.2881e-08, 9.2377e-08,
#          7.7886e-08, 9.1283e-08, 1.2937e-08, 1.3961e-07, 1.7822e-07]))

# %% [markdown]
# ## Inference 7

# %%
img = Image.open(f'{img_path}/panjabi2.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=192x256>

# %%
model.predict(f'{img_path}/panjabi2.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Bangladeshi Panjabi',
#  tensor(1),
#  tensor([5.4238e-04, 9.1014e-01, 3.6290e-05, 6.5101e-04, 8.9250e-06, 1.4996e-03,
#          1.8535e-05, 8.4207e-02, 5.7038e-04, 2.6639e-05, 8.6153e-04, 3.0962e-06,
#          8.2235e-05, 5.4589e-05, 3.0662e-05, 1.1985e-03, 6.7978e-05]))

# %% [markdown]
# ## Inference 8

# %%
img = Image.open(f'{img_path}/thobe.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
model.predict(f'{img_path}/thobe.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Middle Eastern Thobe-Dishdasha',
#  tensor(9),
#  tensor([9.9799e-05, 1.0848e-02, 5.8633e-04, 1.2011e-06, 7.9612e-06, 1.6195e-06,
#          9.1588e-07, 1.6495e-05, 2.4177e-06, 9.8350e-01, 1.5634e-03, 3.7017e-05,
#          3.3083e-03, 3.7906e-06, 7.0790e-06, 1.2999e-05, 1.0962e-06]))
